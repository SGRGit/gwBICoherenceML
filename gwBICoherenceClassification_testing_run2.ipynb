# %% [markdown]
# <a href="https://colab.research.google.com/github/SGRGit/gwBICoherenceML/blob/draft/gwBICoherenceClassification_testing_run2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks')

# %%
import os
base_dir = "gdrive/My Drive/Colab Notebooks/gwBICoherenceFiles/"
seta = 'BBH'
setb = 'Glitch'

data_dir = os.path.join(base_dir, 'Data')
seta_data_dir = os.path.join(data_dir, seta)
seta_data_fnnames = os.listdir(seta_data_dir)

setb_data_dir = os.path.join(data_dir, setb)
setb_data_fnnames = os.listdir(setb_data_dir)

# %%
from sklearn import svm, datasets
from sklearn.model_selection import cross_val_score
from keras import regularizers
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import cv2
q1 = np.empty((1, 150, 150, 3))
q2 = np.empty((1, 150, 150, 3))
for a in range(1, len(seta_data_fnnames), 1):
  img_path_a = os.path.join(seta_data_dir, seta_data_fnnames[a])
  img_a = cv2.imread(os.path.join(seta_data_dir, seta_data_fnnames[a]))
  img_a = cv2.resize(img_a, (150, 150))
  q1 = np.vstack((q1, img_to_array(img_a).reshape(1, 150, 150, 3)))
  t1 = np.ones([len(seta_data_fnnames),1])
  
for b in range(1, len(setb_data_fnnames), 1):
  img_path_b = os.path.join(setb_data_dir, setb_data_fnnames[b])
  img_b = cv2.imread(os.path.join(setb_data_dir, setb_data_fnnames[b]))
  img_b = cv2.resize(img_b, (150, 150))
  q2 = np.vstack((q2, img_to_array(img_b).reshape(1, 150, 150, 3)))
  t2 = np.zeros([len(setb_data_fnnames),1])

# %%
t = np.vstack((t1, t2))
q = np.vstack((q1, q2))

# %%
len(t)
# Out:
# 2652

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(q, t, test_size=0.1, shuffle=True)

# %%
#Import Tensorflow Libraries
from tensorflow.keras import layers
from tensorflow.keras import Model
from keras import regularizers

img_input = layers.Input(shape=(150, 150, 3))

# 2D Conv Layer with 64 filters of dimension 3x3 and ReLU activation function
x = layers.Conv2D(64, 3, activation = 'relu')(img_input)
# 2D Max Pooling Layer
x = layers.MaxPooling2D(2)(x)

# 2D Conv Layer with 128 filters of dimension 3x3 and ReLU activation function
x = layers.Conv2D(128, 3, activation = 'relu')(x)
# 2D Max Pooling Layer
x = layers.MaxPooling2D(2)(x)

# 2D Conv Layer with 256 filters of dimension 3x3 and ReLU activation function
x = layers.Conv2D(256, 3, activation = 'relu')(x)
# 2D Max Pooling Layer
x = layers.MaxPooling2D(2)(x)

# 2D Conv Layer with 512 filters of dimension 3x3 and ReLU activation function
x = layers.Conv2D(512, 3, activation = 'relu')(x)
# 2D Max Pooling Layer
x = layers.MaxPooling2D(2)(x)

# 2D Conv Layer with 512 filters of dimension 3x3 and ReLU activation function
#x = layers.Conv2D(512, 3, activation = 'relu')(x)

# Faltten Layer
x = layers.Flatten()(x)

# Fully Connected Layers and ReLU activation algoritm
x = layers.Dense(4096, activation = 'relu')(x)
x = layers.Dense(4096, activation = 'relu')(x)
x = layers.Dense(1000, activation = 'relu')(x)

# Dropout Layer for Optimization
x = layers.Dropout(0.5,noise_shape=None, seed=None)(x)

# Fully connected layers and sigmoid activation algorithm
output = layers.Dense(1, activation = 'sigmoid')(x)

model = Model(img_input, output)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 148, 148, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 256)       295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 512)       1180160
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              4097000
# _________________________________________________________________
# dropout (Dropout)            (None, 1000)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1001
# =================================================================
# Total params: 125,194,833
# Trainable params: 125,194,833
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
model.compile(loss = 'binary_crossentropy',
             optimizer = tf.train.AdamOptimizer(learning_rate = 0.0005),
             metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Train model (use 10% of training set as validation set)
#model.fit(X_train, y_train, validation_split=0.1, epochs=5, batch_size=10, verbose=2)

history = model.fit(
    X_train,
    y_train,
    epochs=7,
    batch_size=256,
    validation_split=0.1,
    verbose = 1,
    shuffle=True
)

# Train model (use validation data as validation set)
#model.fit(X_train, Y_train, validation_data=(X_test, Y_test))
# Out:
# Train on 2147 samples, validate on 239 samples
# Epoch 1/7
# 2147/2147 [==============================] - 385s 179ms/sample - loss: 107.7917 - acc: 0.5030 - val_loss: 1.4802 - val_acc: 0.4435
# Epoch 2/7
# 2147/2147 [==============================] - 377s 176ms/sample - loss: 0.8156 - acc: 0.5272 - val_loss: 0.6707 - val_acc: 0.5732
# Epoch 3/7
# 2147/2147 [==============================] - 371s 173ms/sample - loss: 0.6841 - acc: 0.5599 - val_loss: 0.6760 - val_acc: 0.5732
# Epoch 4/7
# 2147/2147 [==============================] - 370s 173ms/sample - loss: 0.6791 - acc: 0.5752 - val_loss: 0.6606 - val_acc: 0.5732
# Epoch 5/7
# 2147/2147 [==============================] - 374s 174ms/sample - loss: 0.7835 - acc: 0.5831 - val_loss: 0.6859 - val_acc: 0.4895
# Epoch 6/7
# 2147/2147 [==============================] - 371s 173ms/sample - loss: 0.7222 - acc: 0.4979 - val_loss: 0.6794 - val_acc: 0.5649
# Epoch 7/7
# 2147/2147 [==============================] - 371s 173ms/sample - loss: 0.6744 - acc: 0.5925 - val_loss: 0.6617 - val_acc: 0.5690

# %%
# evaluate the model
train_acc = model.evaluate(X_train, y_train, verbose=0)
test_acc = model.evaluate(X_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc[1], test_acc[1]))
# plot history
plt.plot(history.history['acc'], label='train')
plt.plot(history.history['val_acc'], label='test')
plt.legend()
plt.show()
# Out:
# Train: 0.594, Test: 0.613

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('acc')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve
y_pred = model.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred, pos_label=None)

# %%
from sklearn.metrics import auc

# %%
from sklearn.metrics import auc
from sklearn.ensemble import RandomForestClassifier

nsamples, nx, ny, nz = X_train.shape
nsamplesx, nxx, nyx, nzx = X_test.shape
train_dataset = X_train.reshape((nsamples,nx*ny*nz))
test_dataset = X_test.reshape((nsamplesx,nxx*nyx*nzx))

# Supervised transformation based on random forests
rf = RandomForestClassifier(max_depth=3, n_estimators=10)
rf.fit(train_dataset, y_train)

y_pred_rf = rf.predict_proba(test_dataset)[:, 1]
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test, y_pred_rf)
auc_rf = auc(fpr_rf, tpr_rf)
auc = auc(fpr, tpr)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   # This is added back by InteractiveShellApp.init_path()

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
#plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1.0)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Keras (area = {:.3f})'.format(auc))
#plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.show()

# %%
from sklearn.metrics import accuracy_score, hamming_loss

accuracy_score(y_test,  y_pred.round(), normalize=True, sample_weight=None)
hamming_loss(y_test, y_pred.round())

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred.round())
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
print('Confusion Matrix :\n', cm)

from sklearn.metrics import classification_report
target_names = ['class 0', 'class 1']
print('Classioficaton Report :\n', classification_report(y_test, y_pred.round(), target_names=target_names))

from sklearn import metrics
print('Precision score:', metrics.precision_score(y_test, y_pred.round()))
print('Recall score:', metrics.recall_score(y_test, y_pred.round()))
print('f1_score :', metrics.f1_score(y_test, y_pred.round()))  
print('fbeta_score_0.5 :', metrics.fbeta_score(y_test, y_pred.round(), beta=0.5))
print('fbeta_score_1 :', metrics.fbeta_score(y_test, y_pred.round(), beta=1)) 
print('fbeta_score_2 :', metrics.fbeta_score(y_test, y_pred.round(), beta=2)) 
print('precision_recall_fscore_support :', metrics.precision_recall_fscore_support(y_test, y_pred.round(), beta=0.5))
# Out:
# Confusion Matrix :
#  [[0.21138211 0.78861789]
#  [0.04195804 0.95804196]]
# Classioficaton Report :
#                precision    recall  f1-score   support
#
#      class 0       0.81      0.21      0.34       123
#      class 1       0.59      0.96      0.73       143
#
#     accuracy                           0.61       266
#    macro avg       0.70      0.58      0.53       266
# weighted avg       0.69      0.61      0.55       266
#
# Precision score: 0.5854700854700855
# Recall score: 0.958041958041958
# f1_score : 0.7267904509283819
# fbeta_score_0.5 : 0.6348470806302132
# fbeta_score_1 : 0.7267904509283819
# fbeta_score_2 : 0.8498759305210919
# precision_recall_fscore_support : (array([0.8125    , 0.58547009]), array([0.21138211, 0.95804196]), array([0.51792829, 0.63484708]), array([123, 143]))

# %%
y_pred[12]
# Out:
# array([0.54298383], dtype=float32)

# %%
array_to_img(cv2.resize(X_test[12], (300, 300)))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FB885906CF8>

# %%
y_pred[34]
# Out:
# array([0.53910214], dtype=float32)

# %%
array_to_img(cv2.resize(X_test[34], (300, 300)))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FB885906E80>

# %%
setc = 'TestData'

data_dir = os.path.join(base_dir, 'Data')
setc_data_dir = os.path.join(data_dir, setc)
setc_data_fnnames = os.listdir(setc_data_dir)

q3 = np.empty((1, 150, 150, 3))
for c in range(1, len(setc_data_fnnames), 1):
  img_path_c = os.path.join(setc_data_dir, setc_data_fnnames[c])
  img_c = cv2.imread(os.path.join(setc_data_dir, setc_data_fnnames[c]))
  img_c = cv2.resize(img_c, (150, 150))
  q3 = np.vstack((q3, img_to_array(img_c).reshape(1, 150, 150, 3)))
  #t3 = np.zeros([len(setb_data_fnnames),1])

# %%
alist = [[]]
for c in range(1, len(setc_data_fnnames), 1):
  alist.append([setc_data_fnnames[c], model.predict(q3[c].reshape(1, 150, 150, 3))])
#print(alist)

# %%
import pandas as pd
df = pd.DataFrame(alist)
pd.set_option('display.max_rows', df.shape[0]+1)
df['FileName'] = df[0]
df['Probabilty'] = df[1]
df = df.drop(columns=[0, 1])

# %%
df = df.drop(0)

# %%
df
# Out:
#               FileName      Probabilty
# 1     test_data_10.png   [[0.5250853]]
# 2     test_data_11.png  [[0.49022415]]
# 3     test_data_20.png    [[0.528222]]
# 4     test_data_21.png   [[0.5037042]]
# 5     test_data_17.png   [[0.5186523]]
# 6     test_data_14.png   [[0.5193299]]
# 7     test_data_16.png  [[0.51416373]]
# 8     test_data_15.png  [[0.51667506]]
# 9     test_data_13.png   [[0.5095886]]
# 10    test_data_12.png   [[0.5205357]]
# 11    test_data_22.png   [[0.5170534]]
# 12    test_data_23.png   [[0.5192531]]
# 13    test_data_18.png   [[0.5188591]]
# 14    test_data_24.png   [[0.5379481]]
# 15    test_data_25.png    [[0.507977]]
# 16    test_data_26.png  [[0.52335715]]
# 17    test_data_34.png   [[0.5122211]]
# 18    test_data_35.png   [[0.5079046]]
# 19    test_data_29.png    [[0.531533]]
# 20    test_data_27.png   [[0.5313049]]
# 21    test_data_30.png  [[0.50338054]]
# 22    test_data_32.png  [[0.47982228]]
# 23    test_data_28.png  [[0.51719415]]
# 24    test_data_31.png   [[0.5240011]]
# 25    test_data_36.png  [[0.51705277]]
# 26    test_data_37.png   [[0.5517645]]
# 27    test_data_33.png  [[0.53820026]]
# 28    test_data_38.png   [[0.4671022]]
# 29    test_data_39.png  [[0.52971107]]
# 30    test_data_40.png  [[0.51882017]]
# 31    test_data_48.png  [[0.54758954]]
# 32    test_data_43.png  [[0.51968193]]
# 33    test_data_44.png  [[0.50897604]]
# 34    test_data_46.png   [[0.5355474]]
# 35    test_data_42.png   [[0.5595955]]
# 36    test_data_41.png  [[0.53240776]]
# 37    test_data_49.png   [[0.5175543]]
# 38    test_data_59.png   [[0.5277281]]
# 39    test_data_47.png    [[0.510798]]
# 40    test_data_45.png     [[0.50122]]
# 41    test_data_60.png   [[0.5117199]]
# 42    test_data_61.png   [[0.5201986]]
# 43    test_data_62.png   [[0.4756754]]
# 44    test_data_63.png   [[0.4986044]]
# 45    test_data_64.png   [[0.5003154]]
# 46    test_data_65.png   [[0.4992662]]
# 47    test_data_51.png   [[0.5069657]]
# 48    test_data_52.png   [[0.5211106]]
# 49    test_data_67.png   [[0.5122349]]
# 50    test_data_68.png   [[0.5023334]]
# 51    test_data_66.png  [[0.51841986]]
# 52    test_data_53.png  [[0.47015738]]
# 53    test_data_50.png  [[0.49631777]]
# 54    test_data_69.png   [[0.5070084]]
# 55    test_data_54.png  [[0.52421165]]
# 56    test_data_55.png   [[0.5270619]]
# 57    test_data_56.png   [[0.5012558]]
# 58    test_data_57.png  [[0.50925475]]
# 59    test_data_75.png  [[0.51162016]]
# 60    test_data_76.png   [[0.5254991]]
# 61    test_data_70.png   [[0.5135276]]
# 62    test_data_58.png   [[0.5139211]]
# 63    test_data_71.png  [[0.57474416]]
# 64    test_data_72.png  [[0.51800513]]
# 65    test_data_73.png    [[0.505629]]
# 66    test_data_74.png   [[0.5186326]]
# 67    test_data_77.png   [[0.5235181]]
# 68    test_data_78.png  [[0.52936345]]
# 69    test_data_79.png   [[0.5306836]]
# 70    test_data_80.png   [[0.5256812]]
# 71    test_data_88.png   [[0.5086276]]
# 72    test_data_82.png   [[0.5206265]]
# 73    test_data_83.png  [[0.49934593]]
# 74    test_data_84.png  [[0.56130594]]
# 75    test_data_86.png   [[0.4868121]]
# 76    test_data_85.png  [[0.51074415]]
# 77    test_data_81.png   [[0.5342805]]
# 78    test_data_89.png  [[0.49365214]]
# 79    test_data_87.png   [[0.5028143]]
# 80    test_data_99.png  [[0.51006013]]
# 81   test_data_100.png   [[0.4834357]]
# 82   test_data_108.png   [[0.5401344]]
# 83   test_data_102.png  [[0.43517667]]
# 84   test_data_101.png   [[0.5436887]]
# 85   test_data_103.png  [[0.51815474]]
# 86   test_data_109.png  [[0.51033795]]
# 87   test_data_110.png   [[0.5403426]]
# 88   test_data_111.png   [[0.4571895]]
# 89   test_data_112.png  [[0.49099964]]
# 90   test_data_113.png  [[0.53765553]]
# 91   test_data_114.png  [[0.44039348]]
# 92   test_data_115.png    [[0.444569]]
# 93   test_data_104.png   [[0.5154539]]
# 94   test_data_106.png   [[0.4878099]]
# 95   test_data_105.png  [[0.47668412]]
# 96   test_data_107.png   [[0.5204039]]
# 97   test_data_116.png   [[0.5001819]]
# 98   test_data_117.png  [[0.45672914]]
# 99   test_data_119.png   [[0.4377996]]
# 100  test_data_118.png  [[0.53478754]]
# 101  test_data_125.png   [[0.5186698]]
# 102  test_data_126.png  [[0.47908074]]
# 103  test_data_127.png  [[0.50813216]]
# 104  test_data_121.png   [[0.5570184]]
# 105  test_data_124.png   [[0.5320836]]
# 106  test_data_123.png  [[0.51890695]]
# 107  test_data_120.png   [[0.5393228]]
# 108  test_data_122.png   [[0.5135985]]
# 109  test_data_128.png  [[0.51754045]]
# 110  test_data_129.png  [[0.49647322]]
# 111  test_data_130.png  [[0.52008533]]
# 112  test_data_138.png   [[0.5161732]]
# 113  test_data_131.png   [[0.4978022]]
# 114  test_data_133.png   [[0.5228986]]
# 115  test_data_132.png   [[0.5235436]]
# 116  test_data_134.png  [[0.53177977]]
# 117  test_data_139.png  [[0.52058196]]
# 118   test_data_90.png   [[0.5083298]]
# 119  test_data_136.png  [[0.51803106]]
# 120  test_data_137.png  [[0.52508163]]
# 121  test_data_135.png  [[0.49862656]]
# 122   test_data_91.png  [[0.52482104]]
# 123   test_data_92.png  [[0.53523755]]
# 124   test_data_93.png   [[0.5029748]]
# 125   test_data_02.png  [[0.54837817]]
# 126   test_data_03.png   [[0.5126646]]
# 127   test_data_97.png   [[0.5101352]]
# 128   test_data_95.png  [[0.54545677]]
# 129   test_data_94.png   [[0.5232025]]
# 130   test_data_96.png   [[0.5118715]]
# 131   test_data_04.png   [[0.5176043]]
# 132   test_data_01.png  [[0.54761654]]
# 133   test_data_98.png  [[0.54177135]]
# 134  test_data_140.png   [[0.5230625]]
# 135   test_data_05.png   [[0.5195675]]
# 136   test_data_06.png    [[0.522518]]
# 137   test_data_07.png   [[0.5390931]]
# 138   test_data_08.png   [[0.5199386]]
# 139   test_data_09.png   [[0.5235658]]

# %%
df[df['Probabilty'] > 0.5]
# Out:
#               FileName      Probabilty
# 1     test_data_10.png   [[0.5250853]]
# 3     test_data_20.png    [[0.528222]]
# 4     test_data_21.png   [[0.5037042]]
# 5     test_data_17.png   [[0.5186523]]
# 6     test_data_14.png   [[0.5193299]]
# 7     test_data_16.png  [[0.51416373]]
# 8     test_data_15.png  [[0.51667506]]
# 9     test_data_13.png   [[0.5095886]]
# 10    test_data_12.png   [[0.5205357]]
# 11    test_data_22.png   [[0.5170534]]
# 12    test_data_23.png   [[0.5192531]]
# 13    test_data_18.png   [[0.5188591]]
# 14    test_data_24.png   [[0.5379481]]
# 15    test_data_25.png    [[0.507977]]
# 16    test_data_26.png  [[0.52335715]]
# 17    test_data_34.png   [[0.5122211]]
# 18    test_data_35.png   [[0.5079046]]
# 19    test_data_29.png    [[0.531533]]
# 20    test_data_27.png   [[0.5313049]]
# 21    test_data_30.png  [[0.50338054]]
# 23    test_data_28.png  [[0.51719415]]
# 24    test_data_31.png   [[0.5240011]]
# 25    test_data_36.png  [[0.51705277]]
# 26    test_data_37.png   [[0.5517645]]
# 27    test_data_33.png  [[0.53820026]]
# 29    test_data_39.png  [[0.52971107]]
# 30    test_data_40.png  [[0.51882017]]
# 31    test_data_48.png  [[0.54758954]]
# 32    test_data_43.png  [[0.51968193]]
# 33    test_data_44.png  [[0.50897604]]
# 34    test_data_46.png   [[0.5355474]]
# 35    test_data_42.png   [[0.5595955]]
# 36    test_data_41.png  [[0.53240776]]
# 37    test_data_49.png   [[0.5175543]]
# 38    test_data_59.png   [[0.5277281]]
# 39    test_data_47.png    [[0.510798]]
# 40    test_data_45.png     [[0.50122]]
# 41    test_data_60.png   [[0.5117199]]
# 42    test_data_61.png   [[0.5201986]]
# 45    test_data_64.png   [[0.5003154]]
# 47    test_data_51.png   [[0.5069657]]
# 48    test_data_52.png   [[0.5211106]]
# 49    test_data_67.png   [[0.5122349]]
# 50    test_data_68.png   [[0.5023334]]
# 51    test_data_66.png  [[0.51841986]]
# 54    test_data_69.png   [[0.5070084]]
# 55    test_data_54.png  [[0.52421165]]
# 56    test_data_55.png   [[0.5270619]]
# 57    test_data_56.png   [[0.5012558]]
# 58    test_data_57.png  [[0.50925475]]
# 59    test_data_75.png  [[0.51162016]]
# 60    test_data_76.png   [[0.5254991]]
# 61    test_data_70.png   [[0.5135276]]
# 62    test_data_58.png   [[0.5139211]]
# 63    test_data_71.png  [[0.57474416]]
# 64    test_data_72.png  [[0.51800513]]
# 65    test_data_73.png    [[0.505629]]
# 66    test_data_74.png   [[0.5186326]]
# 67    test_data_77.png   [[0.5235181]]
# 68    test_data_78.png  [[0.52936345]]
# 69    test_data_79.png   [[0.5306836]]
# 70    test_data_80.png   [[0.5256812]]
# 71    test_data_88.png   [[0.5086276]]
# 72    test_data_82.png   [[0.5206265]]
# 74    test_data_84.png  [[0.56130594]]
# 76    test_data_85.png  [[0.51074415]]
# 77    test_data_81.png   [[0.5342805]]
# 79    test_data_87.png   [[0.5028143]]
# 80    test_data_99.png  [[0.51006013]]
# 82   test_data_108.png   [[0.5401344]]
# 84   test_data_101.png   [[0.5436887]]
# 85   test_data_103.png  [[0.51815474]]
# 86   test_data_109.png  [[0.51033795]]
# 87   test_data_110.png   [[0.5403426]]
# 90   test_data_113.png  [[0.53765553]]
# 93   test_data_104.png   [[0.5154539]]
# 96   test_data_107.png   [[0.5204039]]
# 97   test_data_116.png   [[0.5001819]]
# 100  test_data_118.png  [[0.53478754]]
# 101  test_data_125.png   [[0.5186698]]
# 103  test_data_127.png  [[0.50813216]]
# 104  test_data_121.png   [[0.5570184]]
# 105  test_data_124.png   [[0.5320836]]
# 106  test_data_123.png  [[0.51890695]]
# 107  test_data_120.png   [[0.5393228]]
# 108  test_data_122.png   [[0.5135985]]
# 109  test_data_128.png  [[0.51754045]]
# 111  test_data_130.png  [[0.52008533]]
# 112  test_data_138.png   [[0.5161732]]
# 114  test_data_133.png   [[0.5228986]]
# 115  test_data_132.png   [[0.5235436]]
# 116  test_data_134.png  [[0.53177977]]
# 117  test_data_139.png  [[0.52058196]]
# 118   test_data_90.png   [[0.5083298]]
# 119  test_data_136.png  [[0.51803106]]
# 120  test_data_137.png  [[0.52508163]]
# 122   test_data_91.png  [[0.52482104]]
# 123   test_data_92.png  [[0.53523755]]
# 124   test_data_93.png   [[0.5029748]]
# 125   test_data_02.png  [[0.54837817]]
# 126   test_data_03.png   [[0.5126646]]
# 127   test_data_97.png   [[0.5101352]]
# 128   test_data_95.png  [[0.54545677]]
# 129   test_data_94.png   [[0.5232025]]
# 130   test_data_96.png   [[0.5118715]]
# 131   test_data_04.png   [[0.5176043]]
# 132   test_data_01.png  [[0.54761654]]
# 133   test_data_98.png  [[0.54177135]]
# 134  test_data_140.png   [[0.5230625]]
# 135   test_data_05.png   [[0.5195675]]
# 136   test_data_06.png    [[0.522518]]
# 137   test_data_07.png   [[0.5390931]]
# 138   test_data_08.png   [[0.5199386]]
# 139   test_data_09.png   [[0.5235658]]

# %%
cal_bbh = 0
cal_glitch = 0
cal_unconclusive = 0

blist=[]
for c in range(1, len(setc_data_fnnames), 1):
  if model.predict(q3[[c]]) > 0.5:
    #blist.append([setc_data_fnnames[c], 'b'])
    cal_bbh+=1
  elif(model.predict(q3[[c]]) < 0.5):
    #blist.append([setc_data_fnnames[c], 'g'])
    cal_glitch+=1
  else:
    #blist.append([setc_data_fnnames[c], 'u'])
    cal_unconclusive+=1

#print(blist)
print("Identified as: \n")
print("BBH :", cal_bbh)
print("Glitch :", cal_glitch)
print("Inconclusive :", cal_unconclusive)
print("Percentage :", (cal_bbh/(cal_bbh+cal_unconclusive+cal_glitch))*100)
a = (cal_bbh/(cal_bbh+cal_unconclusive+cal_glitch))*100
# Out:
# Identified as:
#
# BBH : 114
# Glitch : 25
# Inconclusive : 0
# Percentage : 82.01438848920863

# %%
cal_bbh = 0
cal_glitch = 0
cal_unconclusive = 0

#blist=[]
for a in range(1, len(seta_data_fnnames), 1):
  if model.predict(q1[[a]]) > 0.5:
    #blist.append([setc_data_fnnames[c], 'b'])
    cal_bbh+=1
  elif(model.predict(q1[[a]]) < 0.5):
    #blist.append([setc_data_fnnames[c], 'g'])
    cal_glitch+=1
  else:
    #blist.append([setc_data_fnnames[c], 'u'])
    cal_unconclusive+=1

#print(blist)
print("Identified as: \n")
print("BBH :", cal_bbh)
print("Glitch :", cal_glitch)
print("Inconclusive :", cal_unconclusive)
print("Percentage :", (cal_bbh/(cal_bbh+cal_unconclusive+cal_glitch))*100)
a = (cal_bbh/(cal_bbh+cal_unconclusive+cal_glitch))*100
# Out:
# Identified as:
#
# BBH : 1264
# Glitch : 61
# Inconclusive : 0
# Percentage : 95.39622641509435

# %%
cal_bbh = 0
cal_glitch = 0
cal_unconclusive = 0

#blist=[]
for b in range(1, len(setb_data_fnnames), 1):
  if model.predict(q2[[b]]) > 0.5:
    #blist.append([setc_data_fnnames[c], 'b'])
    cal_bbh+=1
  elif(model.predict(q2[[b]]) < 0.5):
    #blist.append([setc_data_fnnames[c], 'g'])
    cal_glitch+=1
  else:
    #blist.append([setc_data_fnnames[c], 'u'])
    cal_unconclusive+=1

#print(blist)
print("Identified as: \n")
print("BBH :", cal_bbh)
print("Glitch :", cal_glitch)
print("Inconclusive :", cal_unconclusive)
print("Percentage :", (cal_glitch/(cal_bbh+cal_unconclusive+cal_glitch))*100)
a = (cal_glitch/(cal_bbh+cal_unconclusive+cal_glitch))*100
# Out:
# Identified as:
#
# BBH : 1010
# Glitch : 315
# Inconclusive : 0
# Percentage : 23.77358490566038
